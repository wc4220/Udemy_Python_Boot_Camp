# %%
# Functions, Code Blocks and While Loops

def my_function(): # If we want to create our own function, we need to define it first
    print("Hello")
    print("Bye")

my_function() # We would need to include an input within the paranthesis to run the function. We are 'calling' the function.

# The main purpose of this is to make the code more concise and more straight forward

# This exercise is done in Reeborg's World website
# Out:
# Hello
# Bye

# %%
# Hurdle 4

'''

def turn_right():
    turn_left()
    turn_left()
    turn_left()

def jump():
    if not at_goal():
        turn_left()
        while wall_on_right():
            move()
        turn_right()
        move()
        turn_right()
        while front_is_clear():
            move()
        if wall_in_front():
            turn_left()
        if not at_goal() and front_is_clear():
            move()

while at_goal() != True:
    if front_is_clear():
        move()
    else:
        jump()

'''

# %%
# Maze Problem - To come back after day 15 to debug the edge case
'''

def turn_right():
    turn_left()
    turn_left()
    turn_left()
    
while not at_goal():
    if right_is_clear():
        turn_right()
        move()
    elif front_is_clear():
        move()
    else:
        turn_left()

'''
